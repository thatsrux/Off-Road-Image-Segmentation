# %% [markdown]
# # Importing the necessary libraries

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms

from Evaluator import Evaluator
from SegmentationModel import SegmentationModel
from Trainer import Trainer

# %% [markdown]
# # Parametri di configurazione

# %%
DATA_ROOT = 'train'
BATCH_SIZE = 8
LEARNING_RATE = 0.001
NUM_EPOCHS = 5
NUM_CLASSES = 9
MODEL_SAVE_PATH = 'saved_model.pth'

# %% [markdown]
# # Impostazione del device

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')  # Configura per utilizzare la GPU
    print(f"Utilizzo GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device('cpu')  # Fallback alla CPU
    print("CUDA non disponibile, utilizzo CPU")
# Out:
# Utilizzo GPU: NVIDIA GeForce RTX 5070 Ti

# %%
from RuralDataset import RuralDataset

dataset = RuralDataset("train")
print("Numero di campioni nel dataset:", len(dataset))
img1 = dataset.__getitem__(1)
# Out:
# Numero di campioni nel dataset: 931

# %% [markdown]
# ## Inizializzazione Transform

# %%
transform = transforms.Compose([
        transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

full_dataset = RuralDataset(root_dir=DATA_ROOT, transform=transform)

# %% [markdown]
# # Divisione del dataset in training e validation

# %%
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(full_dataset, [train_size, val_size])

def collate_fn_gpu(batch):
    images, labels = zip(*batch)
    images = torch.stack(images).to(device, non_blocking=True)
    labels = torch.stack(labels).to(device, non_blocking=True)
    return images, labels

train_loader = DataLoader(
    train_dataset, batch_size=BATCH_SIZE, num_workers=4, shuffle=True,
    pin_memory=True)
val_loader = DataLoader(
    val_dataset, batch_size=BATCH_SIZE, num_workers=4, shuffle=False,
    pin_memory=True)


print(f"Training on {len(train_dataset)} samples, validating on {len(val_dataset)} samples.")
# Out:
# Training on 744 samples, validating on 187 samples.

# %% [markdown]
# # Inizializzazione del modello

# %%
model = SegmentationModel(num_classes=NUM_CLASSES)
model.to(device)
print("Model architecture:")
print(model)
# Out:
# Model architecture:
# SegmentationModel(
#   (enc1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (enc2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dec1): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (dec2): Sequential(
#     (0): ConvTranspose2d(32, 9, kernel_size=(2, 2), stride=(2, 2))
#   )
# )

# %% [markdown]
# ## Definizione della funzione di loss e dell'ottimizzatore

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # Inizializzazione e avvio del training

# %%
trainer = Trainer(model, train_loader, val_loader, criterion, optimizer, device)
print("\nStarting training...")
trainer.run(num_epochs=NUM_EPOCHS, model_save_path=MODEL_SAVE_PATH)
print("Training finished.")
# Out:
# Starting training...
#
# Epoch 1/5
# Batch 1/24, Loss: 2.3034
# Batch 2/24, Loss: 2.2451
# Batch 3/24, Loss: 2.1904
# Batch 4/24, Loss: 2.1936
# Batch 5/24, Loss: 2.1350
# Batch 6/24, Loss: 2.1061
# Batch 7/24, Loss: 2.0978
# Batch 8/24, Loss: 2.1085
# Batch 9/24, Loss: 2.0566
# Batch 10/24, Loss: 2.0499
# Batch 11/24, Loss: 1.9932
# Batch 12/24, Loss: 2.0084
# Batch 13/24, Loss: 1.9569
# Batch 14/24, Loss: 1.9625
# Batch 15/24, Loss: 1.9537
# Batch 16/24, Loss: 1.9304
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 trainer = Trainer(model, train_loader, val_loader, criterion, optimizer, device)
#       2 print("\nStarting training...")
# ----> 3 trainer.run(num_epochs=NUM_EPOCHS, model_save_path=MODEL_SAVE_PATH)
#       4 print("Training finished.")
#
# File ~\Desktop\ML_Project\ml-gr31\Trainer.py:62, in Trainer.run(self, num_epochs, model_save_path)
#      60 for epoch in range(num_epochs):
#      61     print(f"\nEpoch {epoch + 1}/{num_epochs}")
# ---> 62     train_loss = self.train_epoch()
#      63     print(f"Train Loss: {train_loss:.4f}")
#      64     val_iou = self.validate_epoch()
#
# File ~\Desktop\ML_Project\ml-gr31\Trainer.py:18, in Trainer.train_epoch(self)
#      16 self.model.train()
#      17 running_loss = 0.0
# ---> 18 for batch_idx, (images, labels) in enumerate(self.train_loader):
#      19     images = images.to(self.device)
#      20     labels = labels.to(self.device)
#
# File ~\Desktop\ML_Project\ml-gr31\.venv\Lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File ~\Desktop\ML_Project\ml-gr31\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1491, in _MultiProcessingDataLoaderIter._next_data(self)
#    1488     return self._process_data(data, worker_id)
#    1490 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1491 idx, data = self._get_data()
#    1492 self._tasks_outstanding -= 1
#    1493 if self._dataset_kind == _DatasetKind.Iterable:
#    1494     # Check for _IterableDatasetStopIteration
#
# File ~\Desktop\ML_Project\ml-gr31\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1443, in _MultiProcessingDataLoaderIter._get_data(self)
#    1441 elif self._pin_memory:
#    1442     while self._pin_memory_thread.is_alive():
# -> 1443         success, data = self._try_get_data()
#    1444         if success:
#    1445             return data
#
# File ~\Desktop\ML_Project\ml-gr31\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1284, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1271 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1272     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1273     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1281     # Returns a 2-tuple:
#    1282     #   (bool: whether successfully get data, any: data if successful else None)
#    1283     try:
# -> 1284         data = self._data_queue.get(timeout=timeout)
#    1285         return (True, data)
#    1286     except Exception as e:
#    1287         # At timeout and error, we manually check whether any worker has
#    1288         # failed. Note that this is the only mechanism for Windows to detect
#    1289         # worker failures.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1520.0_x64__qbz5n2kfra8p0\Lib\queue.py:213, in Queue.get(self, block, timeout)
#     211 if remaining <= 0.0:
#     212     raise Empty
# --> 213 self.not_empty.wait(remaining)
#     214 if self.is_shutdown and not self._qsize():
#     215     raise ShutDown
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1520.0_x64__qbz5n2kfra8p0\Lib\threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# # Valutazione finale del modello

# %%
evaluator = Evaluator(model, val_loader, device)
metrics = evaluator.evaluate_classification_metrics()

# %%
print(metrics.get('accuracy', 'N/A'))
print(metrics.get('f1_score', 'N/A'))
print(metrics.get('precision', 'N/A'))
print(metrics.get('recall', 'N/A'))
# Out:
# 0.5804212101603049
# N/A
# 0.3990662820844938
# 0.3389058900203538
